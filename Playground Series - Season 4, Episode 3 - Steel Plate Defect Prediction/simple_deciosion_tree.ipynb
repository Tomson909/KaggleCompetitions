# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# load in data
df_train = pd.read_csv('/home/tomruge/Schreibtisch/Data/Kaggle/playground-series-s4e3/train.csv')
df_test = pd.read_csv('/home/tomruge/Schreibtisch/Data/Kaggle/playground-series-s4e3/test.csv')

# %%
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
from sklearn.tree import DecisionTreeClassifier
import optuna
from sklearn.metrics import roc_auc_score

class model_class:
    def __init__(self, df_train, df_test, target = [], drop = []):
        self.df_train = df_train.drop(columns = drop)
        self.df_test = df_test.drop(columns = drop)
        self.target = target
        self.drop = drop
    
    def fit(self,params):
        mskf = MultilabelStratifiedKFold(n_splits=2, random_state=0, shuffle=True)
        for train_index, test_index in mskf.split(self.df_train, self.df_train[self.target]):
            X_train = self.df_train.loc[train_index].drop(columns = self.target)
            X_test = self.df_train.loc[test_index].drop(columns = self.target)
            y_train = self.df_train.loc[train_index][self.target]
            y_test = self.df_train.loc[test_index][self.target]
            self.model = DecisionTreeClassifier(**params)
            self.model.fit(X_train, y_train)
            y_pred = self.model.predict_proba(X_test)
            # extract the probability of the positive class
            y_pred = np.array([array[:,1] for array in y_pred]).T
            # shape ypred
            print(roc_auc_score(y_test, y_pred))
        #return roc_auc_score(y_test, y_pred), model
    def predict(self, params):
        # fit to all the data
        model = DecisionTreeClassifier(**params)
        model.fit(self.df_train.drop(columns = self.target), self.df_train[self.target])
        prediction =  model.predict_proba(self.df_test)
        y_pred = np.array([array[:,1] for array in prediction]).T
        return y_pred
    
    def objective(self,trial):
        # params for optimizing decision tree, they need to be compatible with eacht other
        params = {
            'max_depth': trial.suggest_int('max_depth', 1, 32),
            'min_samples_split': trial.suggest_int('min_samples_split', 2, 32),
            'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 32),
            'max_features': trial.suggest_int('max_features', 1, 32),
            'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy']),
            'splitter': trial.suggest_categorical('splitter', ['best', 'random'])
        }
        score, _ = self.fit(params)
        return score
     
    def find_params(self):
        study = optuna.create_study(direction='maximize')
        study.optimize(self.objective, n_trials=100)
        return study.best_params

# %%
# make fit
# find good params
target_columns = ['Pastry','Z_Scratch','K_Scatch','Stains','Dirtiness','Bumps','Other_Faults']
drop_columns = ['id']
model = model_class(df_train, df_test, target_columns, drop_columns)
best_params = {'max_depth': 15,
 'min_samples_split': 21,
 'min_samples_leaf': 11,
 'max_features': 21,
 'criterion': 'entropy',
 'splitter': 'best'}
model.fit(params=best_params)

# make predictions and save them
predicted_values = model.predict(params=best_params)
predictions = pd.DataFrame(np.column_stack((df_test['id'].astype('Int32'), predicted_values)), columns = ['id', 'Pastry','Z_Scratch','K_Scatch','Stains','Dirtiness','Bumps','Other_Faults'])

# save predictions
predictions.to_csv('/home/tomruge/Schreibtisch/Data/Kaggle/playground-series-s4e3/predictions_simpledeecisiontree.csv', index = False)
# Out:
# 0.7924164204220878
# 0.7928286530414298

# %%
# find good params
target_columns = ['Pastry','Z_Scratch','K_Scatch','Stains','Dirtiness','Bumps','Other_Faults']
drop_columns = ['id']
model = model(df_train, df_test, target_columns, drop_columns)
best_params = model.find_params()
# Out:
# [I 2024-03-12 17:49:59,690] A new study created in memory with name: no-name-63b4d013-bcca-4587-8e8f-f60ffa6a4ea1
# [I 2024-03-12 17:50:00,585] Trial 0 finished with value: 0.6733550461589655 and parameters: {'max_depth': 25, 'min_samples_split': 26, 'min_samples_leaf': 9, 'max_features': 16, 'criterion': 'gini', 'splitter': 'best'}. Best is trial 0 with value: 0.6733550461589655.
# [I 2024-03-12 17:50:01,336] Trial 1 finished with value: 0.6663140872415705 and parameters: {'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 32, 'max_features': 10, 'criterion': 'gini', 'splitter': 'best'}. Best is trial 0 with value: 0.6733550461589655.
# [I 2024-03-12 17:50:02,012] Trial 2 finished with value: 0.6573009355186963 and parameters: {'max_depth': 21, 'min_samples_split': 20, 'min_samples_leaf': 13, 'max_features': 28, 'criterion': 'gini', 'splitter': 'random'}. Best is trial 0 with value: 0.6733550461589655.
# [I 2024-03-12 17:50:02,643] Trial 3 finished with value: 0.6295247027954473 and parameters: {'max_depth': 26, 'min_samples_split': 29, 'min_samples_leaf': 8, 'max_features': 4, 'criterion': 'entropy', 'splitter': 'random'}. Best is trial 0 with value: 0.6733550461589655.
# [I 2024-03-12 17:50:03,348] Trial 4 finished with value: 0.6094301603379223 and parameters: {'max_depth': 4, 'min_samples_split': 13, 'min_samples_leaf': 14, 'max_features': 12, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 0 with value: 0.6733550461589655.
# [I 2024-03-12 17:50:04,203] Trial 5 finished with value: 0.6815977528321107 and parameters: {'max_depth': 17, 'min_samples_split': 24, 'min_samples_leaf': 27, 'max_features': 24, 'criterion': 'gini', 'splitter': 'best'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:05,003] Trial 6 finished with value: 0.6778337309633994 and parameters: {'max_depth': 21, 'min_samples_split': 26, 'min_samples_leaf': 7, 'max_features': 9, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:05,745] Trial 7 finished with value: 0.670071777622154 and parameters: {'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 22, 'max_features': 5, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:06,415] Trial 8 finished with value: 0.6604281208913901 and parameters: {'max_depth': 14, 'min_samples_split': 28, 'min_samples_leaf': 32, 'max_features': 24, 'criterion': 'entropy', 'splitter': 'random'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:07,110] Trial 9 finished with value: 0.6089071819311155 and parameters: {'max_depth': 4, 'min_samples_split': 27, 'min_samples_leaf': 27, 'max_features': 32, 'criterion': 'gini', 'splitter': 'best'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:07,768] Trial 10 finished with value: 0.6715392023520296 and parameters: {'max_depth': 32, 'min_samples_split': 20, 'min_samples_leaf': 22, 'max_features': 23, 'criterion': 'gini', 'splitter': 'random'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:08,950] Trial 11 finished with value: 0.6727853851414666 and parameters: {'max_depth': 19, 'min_samples_split': 22, 'min_samples_leaf': 3, 'max_features': 18, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:09,895] Trial 12 finished with value: 0.6704626773060951 and parameters: {'max_depth': 10, 'min_samples_split': 32, 'min_samples_leaf': 2, 'max_features': 18, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:10,656] Trial 13 finished with value: 0.670639246667948 and parameters: {'max_depth': 24, 'min_samples_split': 15, 'min_samples_leaf': 21, 'max_features': 9, 'criterion': 'gini', 'splitter': 'best'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:11,316] Trial 14 finished with value: 0.6154250969549077 and parameters: {'max_depth': 9, 'min_samples_split': 23, 'min_samples_leaf': 17, 'max_features': 1, 'criterion': 'gini', 'splitter': 'best'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:12,468] Trial 15 finished with value: 0.6726841301833469 and parameters: {'max_depth': 32, 'min_samples_split': 17, 'min_samples_leaf': 7, 'max_features': 24, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:13,235] Trial 16 finished with value: 0.6729915556320657 and parameters: {'max_depth': 21, 'min_samples_split': 32, 'min_samples_leaf': 27, 'max_features': 13, 'criterion': 'gini', 'splitter': 'best'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:14,248] Trial 17 finished with value: 0.6751997982206289 and parameters: {'max_depth': 17, 'min_samples_split': 24, 'min_samples_leaf': 18, 'max_features': 20, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:14,956] Trial 18 finished with value: 0.6531501495140847 and parameters: {'max_depth': 27, 'min_samples_split': 11, 'min_samples_leaf': 27, 'max_features': 29, 'criterion': 'entropy', 'splitter': 'random'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:15,669] Trial 19 finished with value: 0.6600529988776097 and parameters: {'max_depth': 13, 'min_samples_split': 18, 'min_samples_leaf': 12, 'max_features': 6, 'criterion': 'gini', 'splitter': 'best'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:16,429] Trial 20 finished with value: 0.6590859570768525 and parameters: {'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 15, 'criterion': 'gini', 'splitter': 'best'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:17,514] Trial 21 finished with value: 0.6770540165192538 and parameters: {'max_depth': 17, 'min_samples_split': 25, 'min_samples_leaf': 18, 'max_features': 21, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:18,656] Trial 22 finished with value: 0.6734891873242761 and parameters: {'max_depth': 21, 'min_samples_split': 24, 'min_samples_leaf': 19, 'max_features': 27, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 5 with value: 0.6815977528321107.
# [I 2024-03-12 17:50:19,699] Trial 23 finished with value: 0.687583283164731 and parameters: {'max_depth': 15, 'min_samples_split': 21, 'min_samples_leaf': 11, 'max_features': 21, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:20,785] Trial 24 finished with value: 0.6696105089265705 and parameters: {'max_depth': 15, 'min_samples_split': 20, 'min_samples_leaf': 11, 'max_features': 20, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:22,031] Trial 25 finished with value: 0.6781341635899159 and parameters: {'max_depth': 23, 'min_samples_split': 29, 'min_samples_leaf': 15, 'max_features': 25, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:22,713] Trial 26 finished with value: 0.671175230584298 and parameters: {'max_depth': 29, 'min_samples_split': 29, 'min_samples_leaf': 14, 'max_features': 25, 'criterion': 'entropy', 'splitter': 'random'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:23,779] Trial 27 finished with value: 0.6757488067725461 and parameters: {'max_depth': 23, 'min_samples_split': 31, 'min_samples_leaf': 25, 'max_features': 31, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:24,581] Trial 28 finished with value: 0.650305013798693 and parameters: {'max_depth': 7, 'min_samples_split': 22, 'min_samples_leaf': 16, 'max_features': 26, 'criterion': 'gini', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:25,235] Trial 29 finished with value: 0.5602629743878318 and parameters: {'max_depth': 1, 'min_samples_split': 30, 'min_samples_leaf': 10, 'max_features': 22, 'criterion': 'gini', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:26,435] Trial 30 finished with value: 0.6823208284171839 and parameters: {'max_depth': 19, 'min_samples_split': 26, 'min_samples_leaf': 15, 'max_features': 30, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:27,759] Trial 31 finished with value: 0.6822859846347015 and parameters: {'max_depth': 19, 'min_samples_split': 26, 'min_samples_leaf': 15, 'max_features': 29, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:28,919] Trial 32 finished with value: 0.6724516184197545 and parameters: {'max_depth': 18, 'min_samples_split': 26, 'min_samples_leaf': 20, 'max_features': 30, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:30,141] Trial 33 finished with value: 0.6816570022679633 and parameters: {'max_depth': 15, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_features': 28, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:31,334] Trial 34 finished with value: 0.680972032242065 and parameters: {'max_depth': 15, 'min_samples_split': 16, 'min_samples_leaf': 9, 'max_features': 28, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:32,081] Trial 35 finished with value: 0.6732886488241308 and parameters: {'max_depth': 12, 'min_samples_split': 19, 'min_samples_leaf': 5, 'max_features': 32, 'criterion': 'entropy', 'splitter': 'random'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:33,318] Trial 36 finished with value: 0.6809481134505321 and parameters: {'max_depth': 19, 'min_samples_split': 22, 'min_samples_leaf': 13, 'max_features': 29, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:34,607] Trial 37 finished with value: 0.6810187758687788 and parameters: {'max_depth': 15, 'min_samples_split': 12, 'min_samples_leaf': 11, 'max_features': 27, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:35,792] Trial 38 finished with value: 0.6819256537605269 and parameters: {'max_depth': 19, 'min_samples_split': 14, 'min_samples_leaf': 15, 'max_features': 30, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:36,538] Trial 39 finished with value: 0.6669463330952229 and parameters: {'max_depth': 20, 'min_samples_split': 9, 'min_samples_leaf': 16, 'max_features': 30, 'criterion': 'entropy', 'splitter': 'random'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:37,828] Trial 40 finished with value: 0.6817438030119177 and parameters: {'max_depth': 11, 'min_samples_split': 15, 'min_samples_leaf': 14, 'max_features': 31, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:39,035] Trial 41 finished with value: 0.6813973065245846 and parameters: {'max_depth': 13, 'min_samples_split': 15, 'min_samples_leaf': 15, 'max_features': 32, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:40,202] Trial 42 finished with value: 0.681737411299365 and parameters: {'max_depth': 11, 'min_samples_split': 14, 'min_samples_leaf': 14, 'max_features': 30, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:41,341] Trial 43 finished with value: 0.6813352933648306 and parameters: {'max_depth': 22, 'min_samples_split': 27, 'min_samples_leaf': 14, 'max_features': 26, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:42,573] Trial 44 finished with value: 0.6795008746735945 and parameters: {'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 12, 'max_features': 31, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:43,834] Trial 45 finished with value: 0.6741475935192097 and parameters: {'max_depth': 26, 'min_samples_split': 13, 'min_samples_leaf': 8, 'max_features': 29, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:45,021] Trial 46 finished with value: 0.6782117956297034 and parameters: {'max_depth': 16, 'min_samples_split': 21, 'min_samples_leaf': 17, 'max_features': 27, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:45,672] Trial 47 finished with value: 0.6232913472122777 and parameters: {'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 23, 'max_features': 23, 'criterion': 'entropy', 'splitter': 'random'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:46,651] Trial 48 finished with value: 0.6722145153472274 and parameters: {'max_depth': 18, 'min_samples_split': 17, 'min_samples_leaf': 12, 'max_features': 16, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:47,770] Trial 49 finished with value: 0.68467407678218 and parameters: {'max_depth': 10, 'min_samples_split': 27, 'min_samples_leaf': 18, 'max_features': 32, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:48,798] Trial 50 finished with value: 0.6729923708426205 and parameters: {'max_depth': 20, 'min_samples_split': 28, 'min_samples_leaf': 19, 'max_features': 18, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:49,879] Trial 51 finished with value: 0.683589229082031 and parameters: {'max_depth': 11, 'min_samples_split': 25, 'min_samples_leaf': 15, 'max_features': 32, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:50,880] Trial 52 finished with value: 0.680864784105763 and parameters: {'max_depth': 9, 'min_samples_split': 27, 'min_samples_leaf': 16, 'max_features': 31, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:52,036] Trial 53 finished with value: 0.6758479215925454 and parameters: {'max_depth': 13, 'min_samples_split': 25, 'min_samples_leaf': 18, 'max_features': 32, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:52,835] Trial 54 finished with value: 0.6540023321386226 and parameters: {'max_depth': 5, 'min_samples_split': 23, 'min_samples_leaf': 15, 'max_features': 29, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:53,916] Trial 55 finished with value: 0.6815055148872275 and parameters: {'max_depth': 10, 'min_samples_split': 26, 'min_samples_leaf': 21, 'max_features': 30, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:54,968] Trial 56 finished with value: 0.6713728382393782 and parameters: {'max_depth': 16, 'min_samples_split': 24, 'min_samples_leaf': 13, 'max_features': 14, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:56,247] Trial 57 finished with value: 0.6801487001134625 and parameters: {'max_depth': 14, 'min_samples_split': 28, 'min_samples_leaf': 17, 'max_features': 28, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:56,972] Trial 58 finished with value: 0.6516873520534163 and parameters: {'max_depth': 18, 'min_samples_split': 21, 'min_samples_leaf': 19, 'max_features': 32, 'criterion': 'entropy', 'splitter': 'random'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:58,137] Trial 59 finished with value: 0.673371439688876 and parameters: {'max_depth': 22, 'min_samples_split': 25, 'min_samples_leaf': 29, 'max_features': 26, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:50:59,144] Trial 60 finished with value: 0.678273574962705 and parameters: {'max_depth': 12, 'min_samples_split': 30, 'min_samples_leaf': 23, 'max_features': 10, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:00,247] Trial 61 finished with value: 0.684374672529209 and parameters: {'max_depth': 10, 'min_samples_split': 27, 'min_samples_leaf': 13, 'max_features': 31, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:01,262] Trial 62 finished with value: 0.6668475145836626 and parameters: {'max_depth': 8, 'min_samples_split': 27, 'min_samples_leaf': 13, 'max_features': 30, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:02,345] Trial 63 finished with value: 0.6812271306519702 and parameters: {'max_depth': 9, 'min_samples_split': 23, 'min_samples_leaf': 11, 'max_features': 32, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:03,480] Trial 64 finished with value: 0.6855938168402942 and parameters: {'max_depth': 10, 'min_samples_split': 25, 'min_samples_leaf': 15, 'max_features': 29, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:04,447] Trial 65 finished with value: 0.6657636358638375 and parameters: {'max_depth': 10, 'min_samples_split': 26, 'min_samples_leaf': 18, 'max_features': 28, 'criterion': 'gini', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:05,417] Trial 66 finished with value: 0.650376632631204 and parameters: {'max_depth': 7, 'min_samples_split': 25, 'min_samples_leaf': 9, 'max_features': 25, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:06,531] Trial 67 finished with value: 0.6813459912293318 and parameters: {'max_depth': 11, 'min_samples_split': 29, 'min_samples_leaf': 13, 'max_features': 29, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:07,679] Trial 68 finished with value: 0.6792414436330096 and parameters: {'max_depth': 14, 'min_samples_split': 30, 'min_samples_leaf': 17, 'max_features': 31, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:08,648] Trial 69 finished with value: 0.6505020664618677 and parameters: {'max_depth': 8, 'min_samples_split': 28, 'min_samples_leaf': 20, 'max_features': 27, 'criterion': 'gini', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:09,577] Trial 70 finished with value: 0.5 and parameters: {'max_depth': 3, 'min_samples_split': 24, 'min_samples_leaf': 10, 'max_features': 1, 'criterion': 'entropy', 'splitter': 'random'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:11,199] Trial 71 finished with value: 0.6819422813671786 and parameters: {'max_depth': 17, 'min_samples_split': 26, 'min_samples_leaf': 15, 'max_features': 31, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:12,408] Trial 72 finished with value: 0.6818231614112908 and parameters: {'max_depth': 17, 'min_samples_split': 27, 'min_samples_leaf': 15, 'max_features': 31, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:13,562] Trial 73 finished with value: 0.6768429507666943 and parameters: {'max_depth': 12, 'min_samples_split': 25, 'min_samples_leaf': 16, 'max_features': 29, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:14,644] Trial 74 finished with value: 0.6815309677509479 and parameters: {'max_depth': 10, 'min_samples_split': 22, 'min_samples_leaf': 12, 'max_features': 32, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:15,830] Trial 75 finished with value: 0.6831414915264098 and parameters: {'max_depth': 14, 'min_samples_split': 23, 'min_samples_leaf': 14, 'max_features': 28, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:16,979] Trial 76 finished with value: 0.680217138168152 and parameters: {'max_depth': 12, 'min_samples_split': 21, 'min_samples_leaf': 14, 'max_features': 28, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:17,975] Trial 77 finished with value: 0.6772261708258196 and parameters: {'max_depth': 14, 'min_samples_split': 23, 'min_samples_leaf': 11, 'max_features': 19, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:18,934] Trial 78 finished with value: 0.6814612309267696 and parameters: {'max_depth': 9, 'min_samples_split': 31, 'min_samples_leaf': 7, 'max_features': 24, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:19,950] Trial 79 finished with value: 0.681567305536212 and parameters: {'max_depth': 13, 'min_samples_split': 19, 'min_samples_leaf': 17, 'max_features': 23, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:20,852] Trial 80 finished with value: 0.6717917441176614 and parameters: {'max_depth': 11, 'min_samples_split': 24, 'min_samples_leaf': 13, 'max_features': 26, 'criterion': 'gini', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:21,940] Trial 81 finished with value: 0.6825500893183643 and parameters: {'max_depth': 16, 'min_samples_split': 26, 'min_samples_leaf': 15, 'max_features': 30, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:23,058] Trial 82 finished with value: 0.6798808530238999 and parameters: {'max_depth': 14, 'min_samples_split': 27, 'min_samples_leaf': 16, 'max_features': 30, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:24,222] Trial 83 finished with value: 0.676751723342975 and parameters: {'max_depth': 16, 'min_samples_split': 26, 'min_samples_leaf': 12, 'max_features': 29, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:25,439] Trial 84 finished with value: 0.6818038418991968 and parameters: {'max_depth': 15, 'min_samples_split': 29, 'min_samples_leaf': 15, 'max_features': 27, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:26,390] Trial 85 finished with value: 0.6606637752125152 and parameters: {'max_depth': 7, 'min_samples_split': 25, 'min_samples_leaf': 14, 'max_features': 31, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:27,615] Trial 86 finished with value: 0.6779422268967864 and parameters: {'max_depth': 20, 'min_samples_split': 22, 'min_samples_leaf': 16, 'max_features': 30, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:28,328] Trial 87 finished with value: 0.6657003181928977 and parameters: {'max_depth': 18, 'min_samples_split': 24, 'min_samples_leaf': 19, 'max_features': 28, 'criterion': 'entropy', 'splitter': 'random'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:29,529] Trial 88 finished with value: 0.6765581361300711 and parameters: {'max_depth': 16, 'min_samples_split': 28, 'min_samples_leaf': 18, 'max_features': 29, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:30,714] Trial 89 finished with value: 0.6815558729710695 and parameters: {'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 12, 'max_features': 32, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:31,813] Trial 90 finished with value: 0.6764983525152182 and parameters: {'max_depth': 11, 'min_samples_split': 23, 'min_samples_leaf': 10, 'max_features': 27, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:32,978] Trial 91 finished with value: 0.6822565915362907 and parameters: {'max_depth': 17, 'min_samples_split': 26, 'min_samples_leaf': 15, 'max_features': 31, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:34,165] Trial 92 finished with value: 0.6804454378508814 and parameters: {'max_depth': 20, 'min_samples_split': 27, 'min_samples_leaf': 14, 'max_features': 30, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:35,300] Trial 93 finished with value: 0.6783526550969444 and parameters: {'max_depth': 19, 'min_samples_split': 26, 'min_samples_leaf': 16, 'max_features': 32, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:36,486] Trial 94 finished with value: 0.6801255886149082 and parameters: {'max_depth': 17, 'min_samples_split': 28, 'min_samples_leaf': 13, 'max_features': 31, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:37,519] Trial 95 finished with value: 0.6768171705510758 and parameters: {'max_depth': 21, 'min_samples_split': 25, 'min_samples_leaf': 17, 'max_features': 21, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:38,706] Trial 96 finished with value: 0.6815661824860071 and parameters: {'max_depth': 15, 'min_samples_split': 24, 'min_samples_leaf': 15, 'max_features': 28, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:39,871] Trial 97 finished with value: 0.6795245380221716 and parameters: {'max_depth': 18, 'min_samples_split': 26, 'min_samples_leaf': 11, 'max_features': 29, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:40,618] Trial 98 finished with value: 0.6536260722804536 and parameters: {'max_depth': 10, 'min_samples_split': 29, 'min_samples_leaf': 14, 'max_features': 6, 'criterion': 'entropy', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
# [I 2024-03-12 17:51:41,466] Trial 99 finished with value: 0.6761679804768258 and parameters: {'max_depth': 9, 'min_samples_split': 27, 'min_samples_leaf': 18, 'max_features': 30, 'criterion': 'gini', 'splitter': 'best'}. Best is trial 23 with value: 0.687583283164731.
